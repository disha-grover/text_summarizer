# %% [markdown]
# # TEXT SUMMARISER
#
# # The Problem
# To create a program which allows user to input text they would like to have summarized.
# The program should then take the input and output the summarized version of the input. The output will depend on the parameters given by the user i.e., if they want the summary to a certain lenght of sentences.
#
# # Step 2. Describe the input and output
# **Input**
# * String-Input: Ask user to input text extract which needs summarization
# * Int-Input: Ask user to input max sentence length of summary
# * Yes/No: Yes if user would like to continue again to resummarize, or No if they'd like to exit the program
#
# **Output**
# * Use pypi software, specifically bert extractive summarizer (https://pypi.org/project/bert-extractive-summarizer/)
#
# # Step 3/4. Work problem by hand/ Develop Program
#
# Prompt user for what they would like to have summarizered:
# input("What would you like to have summarized? Please paste extract here. ")
# store as text
#
# Prompt user for how the number of sentences they'd like the summary to be:
# int(input("How many sentences would you like the summary to be? ")
# store as maxsent
#
# From summarizer, import summarizer
#
# summarise = summariser
# result = summarise(text, num_sentences = maxsent)
#
# print(result)
#
# Prompt user if they'd like to continue (WILL REQUIRE A WHILE LOOP).
#
# # Create Final Program
#
# As follows

# %%
# !pip install bert-extractive-summarizer
from summarizer import Summarizer 

print("Welcome to text summarizer!")

while True:
  text = input("What would you like to have summarized? Please paste the extract below. ")
    
  maxsent = int(input("What is the maximum length of sentences you'd like the summarized text to be? "))
    
  summarise = Summarizer()
    
  result = summarise(text, num_sentences = maxsent)
    
  print(result)

  if input("Would you like to continue? Please type Y or N only. ") == "N" :
    break
    print("Thank you for using our text summariser! ")

  else:
    input("Would you like to continue? Please type Y or N. ") == "Y"
    continue
